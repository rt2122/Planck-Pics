# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
# %config InlineBackend.figure_format = 'retina'
from modules.DS_detector import rematch_cat
from modules.DS_models_stat import cut_cat
from mpl_toolkits.mplot3d.axes3d import Axes3D
from mpl_toolkits.mplot3d import proj3d

# %%
df = rematch_cat('./Data/detected_cats/SZcatAL.csv', tp_dist=400/3600, add_fn=True, 
                 clusters_dir='./Data/united_cats/')
name='SZcat(AL)'
df = cut_cat(df, dict_cut={'b' : [20, np.inf], 'l' : [0, 180]})
# Out:
# /home/rt2122/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df = df[df['status'] != 'fp']
df = df[df['catalog'] != 'planck_no_z']
df.index = np.arange(len(df))

# %%
q_z = [df['z'].quantile(i/6) for i in range(0, 7)]
q_z[0] = 0
q_z[-1] = 2
q_m = [df['M500'].quantile(i/10) for i in range(0, 11)]
q_m[0] = 0
q_m[-1] = 20
print(repr(q_z))
print(repr(q_m))
# Out:
# [0, 0.132, 0.24542784770149145, 0.3619915054295486, 0.5017101764678951, 0.6783357500000005, 2]
# [0, 1.0091851, 1.5482460618342797, 1.7928062326120675, 2.0663002020009515, 2.361268179161475, 2.6599745887301767, 3.0171712446820025, 3.6116273147415585, 4.843654899999998, 20]

# %%
q_m500 = {}
for i in range(len(q_z) - 1):
    st = q_z[i]
    en = q_z[i + 1]
    matched = np.logical_and(st <= df['z'], df['z'] < en)
    cur_df = df[matched]
    q_m500[en] = [cur_df['M500'].quantile(i / 10) for i in range(11)]
    q_m500[en][-1] = 20

# %%
q_m500 = pd.DataFrame(q_m500)
q_m500
# Out:
#      0.132000   0.245428   0.361992   0.501710   0.678336   2.000000
# 0    0.009600   0.243700   0.324500   0.593800   0.958000   1.087900
# 1    0.282100   0.879300   1.310340   1.547713   1.676748   1.620451
# 2    0.460800   1.342532   1.566980   1.831485   1.881334   1.764139
# 3    0.722500   1.652072   1.918487   2.136176   2.086316   1.936266
# 4    1.020600   2.070290   2.229202   2.369411   2.361919   2.085740
# 5    1.340350   2.511600   2.526098   2.601063   2.618182   2.290804
# 6    1.711900   2.989220   2.963655   2.808671   2.833144   2.534824
# 7    2.105639   3.547388   3.855784   3.165064   3.097159   2.843697
# 8    2.512724   4.125736   4.697928   3.903347   3.391838   3.167899
# 9    3.117283   4.916616   5.634143   5.445230   4.933248   3.761942
# 10  20.000000  20.000000  20.000000  20.000000  20.000000  20.000000

# %%
recalls = []
for j in range(len(q_m500[q_z[1]]) - 1):
    line = {}
    for i in range(len(q_z) - 1):
        z_st = q_z[i]
        z_en = q_z[i + 1]
        m_st = q_m500[z_en][j]
        m_en = q_m500[z_en][j + 1]
        
        matched1 = np.logical_and(z_st <= df['z'], df['z'] < z_en)
        matched2 = np.logical_and(m_st <= df['M500'], df['M500'] < m_en)
        cur_df = df[np.logical_and(matched1, matched2)]
        recall = np.count_nonzero(cur_df['status'] == 'tp') / len(cur_df)
        line['({:.2f},{:.2f})'.format(z_st, z_en)] = recall
    recalls.append(pd.DataFrame(line, index=[j]))
recalls = pd.concat(recalls)

# %%
recalls
# Out:
#    (0.00,0.13)  (0.13,0.25)  (0.25,0.36)  (0.36,0.50)  (0.50,0.68)  \
# 0     0.046512     0.000000     0.069767     0.069767     0.093023
# 1     0.023810     0.093023     0.116279     0.166667     0.093023
# 2     0.046512     0.190476     0.238095     0.139535     0.071429
# 3     0.119048     0.255814     0.139535     0.095238     0.046512
# 4     0.348837     0.238095     0.380952     0.186047     0.119048
# 5     0.476190     0.558140     0.302326     0.190476     0.209302
# 6     0.674419     0.860465     0.604651     0.255814     0.116279
# 7     0.833333     0.880952     0.904762     0.500000     0.121951
# 8     0.837209     0.976744     0.883721     0.720930     0.272727
# 9     0.860465     1.000000     0.976744     1.000000     0.976744
#
#    (0.68,2.00)
# 0     0.069767
# 1     0.000000
# 2     0.023810
# 3     0.046512
# 4     0.071429
# 5     0.093023
# 6     0.142857
# 7     0.162791
# 8     0.232558
# 9     0.558140

# %%
cm = sns.light_palette("green", as_cmap=True)

s = recalls.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
# #T_b6162_row0_col0,#T_b6162_row2_col0,#T_b6162_row2_col4{
#             background-color:  #e5f0e5;
#             color:  #000000;
#         }#T_b6162_row0_col1,#T_b6162_row0_col2,#T_b6162_row0_col3,#T_b6162_row1_col0,#T_b6162_row1_col5,#T_b6162_row3_col4{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_b6162_row0_col4,#T_b6162_row1_col4{
#             background-color:  #e0eedf;
#             color:  #000000;
#         }#T_b6162_row0_col5,#T_b6162_row4_col3,#T_b6162_row4_col5{
#             background-color:  #cde5cd;
#             color:  #000000;
#         }#T_b6162_row1_col1{
#             background-color:  #d5e9d5;
#             color:  #000000;
#         }#T_b6162_row1_col2{
#             background-color:  #dfeddf;
#             color:  #000000;
#         }#T_b6162_row1_col3{
#             background-color:  #d3e7d3;
#             color:  #000000;
#         }#T_b6162_row2_col1{
#             background-color:  #beddbe;
#             color:  #000000;
#         }#T_b6162_row2_col2{
#             background-color:  #bfdebf;
#             color:  #000000;
#         }#T_b6162_row2_col3,#T_b6162_row3_col2,#T_b6162_row4_col4,#T_b6162_row6_col4{
#             background-color:  #d9ead9;
#             color:  #000000;
#         }#T_b6162_row2_col5{
#             background-color:  #e1eee1;
#             color:  #000000;
#         }#T_b6162_row3_col0{
#             background-color:  #d0e6d0;
#             color:  #000000;
#         }#T_b6162_row3_col1,#T_b6162_row5_col2,#T_b6162_row6_col5{
#             background-color:  #afd6af;
#             color:  #000000;
#         }#T_b6162_row3_col3{
#             background-color:  #e4f0e4;
#             color:  #000000;
#         }#T_b6162_row3_col5{
#             background-color:  #d7e9d7;
#             color:  #000000;
#         }#T_b6162_row4_col0{
#             background-color:  #8fc68f;
#             color:  #000000;
#         }#T_b6162_row4_col1{
#             background-color:  #b3d8b3;
#             color:  #000000;
#         }#T_b6162_row4_col2{
#             background-color:  #9bcc9b;
#             color:  #000000;
#         }#T_b6162_row5_col0{
#             background-color:  #6cb56c;
#             color:  #000000;
#         }#T_b6162_row5_col1{
#             background-color:  #68b368;
#             color:  #000000;
#         }#T_b6162_row5_col3{
#             background-color:  #cce4cc;
#             color:  #000000;
#         }#T_b6162_row5_col4{
#             background-color:  #c2dfc2;
#             color:  #000000;
#         }#T_b6162_row5_col5{
#             background-color:  #c4e0c4;
#             color:  #000000;
#         }#T_b6162_row6_col0{
#             background-color:  #349934;
#             color:  #000000;
#         }#T_b6162_row6_col1{
#             background-color:  #209020;
#             color:  #000000;
#         }#T_b6162_row6_col2{
#             background-color:  #61af61;
#             color:  #000000;
#         }#T_b6162_row6_col3{
#             background-color:  #bcdcbc;
#             color:  #000000;
#         }#T_b6162_row7_col0{
#             background-color:  #078407;
#             color:  #f1f1f1;
#         }#T_b6162_row7_col1{
#             background-color:  #1c8e1c;
#             color:  #000000;
#         }#T_b6162_row7_col2{
#             background-color:  #128912;
#             color:  #f1f1f1;
#         }#T_b6162_row7_col3{
#             background-color:  #7ebe7e;
#             color:  #000000;
#         }#T_b6162_row7_col4{
#             background-color:  #d8ead8;
#             color:  #000000;
#         }#T_b6162_row7_col5{
#             background-color:  #a6d2a6;
#             color:  #000000;
#         }#T_b6162_row8_col0{
#             background-color:  #068306;
#             color:  #f1f1f1;
#         }#T_b6162_row8_col1{
#             background-color:  #058205;
#             color:  #f1f1f1;
#         }#T_b6162_row8_col2{
#             background-color:  #188c18;
#             color:  #000000;
#         }#T_b6162_row8_col3{
#             background-color:  #46a246;
#             color:  #000000;
#         }#T_b6162_row8_col4{
#             background-color:  #b2d7b1;
#             color:  #000000;
#         }#T_b6162_row8_col5{
#             background-color:  #89c389;
#             color:  #000000;
#         }#T_b6162_row9_col0,#T_b6162_row9_col1,#T_b6162_row9_col2,#T_b6162_row9_col3,#T_b6162_row9_col4,#T_b6162_row9_col5{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }</style><table id="T_b6162_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >(0.00,0.13)</th>        <th class="col_heading level0 col1" >(0.13,0.25)</th>        <th class="col_heading level0 col2" >(0.25,0.36)</th>        <th class="col_heading level0 col3" >(0.36,0.50)</th>        <th class="col_heading level0 col4" >(0.50,0.68)</th>        <th class="col_heading level0 col5" >(0.68,2.00)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b6162_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b6162_row0_col0" class="data row0 col0" >0.046512</td>
#                         <td id="T_b6162_row0_col1" class="data row0 col1" >0.000000</td>
#                         <td id="T_b6162_row0_col2" class="data row0 col2" >0.069767</td>
#                         <td id="T_b6162_row0_col3" class="data row0 col3" >0.069767</td>
#                         <td id="T_b6162_row0_col4" class="data row0 col4" >0.093023</td>
#                         <td id="T_b6162_row0_col5" class="data row0 col5" >0.069767</td>
#             </tr>
#             <tr>
#                         <th id="T_b6162_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b6162_row1_col0" class="data row1 col0" >0.023810</td>
#                         <td id="T_b6162_row1_col1" class="data row1 col1" >0.093023</td>
#                         <td id="T_b6162_row1_col2" class="data row1 col2" >0.116279</td>
#                         <td id="T_b6162_row1_col3" class="data row1 col3" >0.166667</td>
#                         <td id="T_b6162_row1_col4" class="data row1 col4" >0.093023</td>
#                         <td id="T_b6162_row1_col5" class="data row1 col5" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b6162_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b6162_row2_col0" class="data row2 col0" >0.046512</td>
#                         <td id="T_b6162_row2_col1" class="data row2 col1" >0.190476</td>
#                         <td id="T_b6162_row2_col2" class="data row2 col2" >0.238095</td>
#                         <td id="T_b6162_row2_col3" class="data row2 col3" >0.139535</td>
#                         <td id="T_b6162_row2_col4" class="data row2 col4" >0.071429</td>
#                         <td id="T_b6162_row2_col5" class="data row2 col5" >0.023810</td>
#             </tr>
#             <tr>
#                         <th id="T_b6162_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b6162_row3_col0" class="data row3 col0" >0.119048</td>
#                         <td id="T_b6162_row3_col1" class="data row3 col1" >0.255814</td>
#                         <td id="T_b6162_row3_col2" class="data row3 col2" >0.139535</td>
#                         <td id="T_b6162_row3_col3" class="data row3 col3" >0.095238</td>
#                         <td id="T_b6162_row3_col4" class="data row3 col4" >0.046512</td>
#                         <td id="T_b6162_row3_col5" class="data row3 col5" >0.046512</td>
#             </tr>
#             <tr>
#                         <th id="T_b6162_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b6162_row4_col0" class="data row4 col0" >0.348837</td>
#                         <td id="T_b6162_row4_col1" class="data row4 col1" >0.238095</td>
#                         <td id="T_b6162_row4_col2" class="data row4 col2" >0.380952</td>
#                         <td id="T_b6162_row4_col3" class="data row4 col3" >0.186047</td>
#                         <td id="T_b6162_row4_col4" class="data row4 col4" >0.1190

# %%
nums = []
for j in range(len(q_m500) - 1):
    line = {}
    for i in range(len(q_z) - 1):
        z_st = q_z[i]
        z_en = q_z[i + 1]
        m_st = q_m500[z_en][j]
        m_en = q_m500[z_en][j + 1]
        
        matched1 = np.logical_and(z_st <= df['z'], df['z'] < z_en)
        matched2 = np.logical_and(m_st <= df['M500'], df['M500'] < m_en)
        cur_df = df[np.logical_and(matched1, matched2)]
        num = len(cur_df)
        line['({:.2f},{:.2f})'.format(z_st, z_en)] = num
    nums.append(pd.DataFrame(line, index=[j]))
nums = pd.concat(nums)

# %%
nums
# Out:
#    (0.00,0.13)  (0.13,0.25)  (0.25,0.36)  (0.36,0.50)  (0.50,0.68)  \
# 0           43           43           43           43           43
# 1           42           43           43           42           43
# 2           43           42           42           43           42
# 3           42           43           43           42           43
# 4           43           42           42           43           42
# 5           42           43           43           42           43
# 6           43           43           43           43           43
# 7           42           42           42           42           41
# 8           43           43           43           43           44
# 9           43           43           43           43           43
#
#    (0.68,2.00)
# 0           43
# 1           43
# 2           42
# 3           43
# 4           42
# 5           43
# 6           42
# 7           43
# 8           43
# 9           43

# %%
nums = []
for j in range(len(q_m) - 1):
    line = {}
    m_st = q_m[j]
    m_en = q_m[j + 1]
    for i in range(len(q_z) - 1):
        z_st = q_z[i]
        z_en = q_z[i + 1]
        
        matched1 = np.logical_and(z_st <= df['z'], df['z'] < z_en)
        matched2 = np.logical_and(m_st <= df['M500'], df['M500'] < m_en)
        cur_df = df[np.logical_and(matched1, matched2)]
        num = len(cur_df)
        line['({:.2f},{:.2f})'.format(z_st, z_en)] = num
    nums.append(pd.DataFrame(line, index=['({:.2f},{:.2f})'.format(m_st, m_en)]))
nums = pd.concat(nums)

# %%
nums
# Out:
#               (0.00,0.13)  (0.13,0.25)  (0.25,0.36)  (0.36,0.50)  (0.50,0.68)  \
# (0.00,1.01)           166           55           28            6            1
# (1.01,1.55)            73           56           52           37           14
# (1.55,1.79)            26           32           37           37           53
# (1.79,2.07)            30           27           32           42           57
# (2.07,2.36)            26           34           38           46           45
# (2.36,2.66)            31           24           43           63           56
# (2.66,3.02)            27           30           28           55           65
# (3.02,3.61)            19           44           36           40           63
# (3.61,4.84)            18           79           58           40           28
# (4.84,20.00)           10           46           75           60           45
#
#               (0.68,2.00)
# (0.00,1.01)             0
# (1.01,1.55)            22
# (1.55,1.79)            72
# (1.79,2.07)            69
# (2.07,2.36)            66
# (2.36,2.66)            39
# (2.66,3.02)            51
# (3.02,3.61)            55
# (3.61,4.84)            33
# (4.84,20.00)           20

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(20, 7))
X, Y = np.meshgrid(q_z[:-1], q_m[:-1])

Z = np.zeros_like(X)

ax.set_zticks(np.arange(0, 1.1, 0.1))
cols = list(recalls)
for i in range(Z.shape[0]):
    for j in range(Z.shape[1]):
        Z[i,j] = recalls[cols[j]].iloc[i]
#X, Y = np.meshgrid(list(range(len(q_z) - 1)), list(range(len(q_m) - 1)))
        
surf = ax.plot_surface(X, Y, Z, cmap='coolwarm',
                       linewidth=0, antialiased=False, alpha=0.9)

# Customize the z axis.
#ax.set_zlim(0, 1.01)
#ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
#ax.zaxis.set_major_formatter('{x:.02f}')
ax.set_xlabel('z')
ax.set_zlabel('recall')
#ax.set_ylabel('M500, M☉ * 10¹⁴')
ax.set_ylabel('M500')

x_scale=2
y_scale=2
z_scale=1.5

scale=np.diag([x_scale, y_scale, z_scale, 1.0])
scale=scale*(1.0/scale.max())
scale[3,3]=1.0

def short_proj():
    return np.dot(Axes3D.get_proj(ax), scale)

ax.get_proj=short_proj
# Add a color bar which maps values to colors.
#fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_title(name)
plt.show()

# %%
df = rematch_cat('./Data/detected_cats/SZcatAL.csv', tp_dist=400/3600, add_fn=False, 
                 clusters_dir='./Data/united_cats/')
name='SZcat(AL)'
df = cut_cat(df, dict_cut={'l' : [0, 180], 'b' : [20, np.inf]})
# Out:
# /home/rt2122/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df = df[df['status'] != 'fp']
df = df[df['catalog'] != 'planck_no_z']
df.index = np.arange(len(df))

# %%
q_z = [df['z'].quantile(i/6) for i in range(0, 7)]
q_z[0] = 0
q_z[-1] = 2
q_m = [df['M500'].quantile(i/10) for i in range(0, 11)]
q_m[0] = 0
q_m[-1] = 20

# %%
q_m500 = {}
for i in range(len(q_z) - 1):
    st = q_z[i]
    en = q_z[i + 1]
    matched = np.logical_and(st <= df['z'], df['z'] < en)
    cur_df = df[matched]
    q_m500[en] = [cur_df['M500'].quantile(i / 10) for i in range(11)]
    q_m500[en][-1] = 20

# %%
q_m500 = pd.DataFrame(q_m500)
q_m500
# Out:
#      0.112667   0.190000   0.269354   0.360249   0.502922   2.000000
# 0    0.153200   0.621400   0.965900   1.200900   1.121300   1.420565
# 1    1.140215   1.644732   2.123726   2.056122   2.095205   2.028535
# 2    1.486657   2.269360   2.899134   2.484924   2.629384   2.531747
# 3    1.797432   2.690733   3.355709   3.099081   2.985969   2.832950
# 4    1.928839   3.002638   3.775312   3.883988   3.491387   3.212295
# 5    2.222597   3.262274   4.110028   4.416942   4.056793   3.649907
# 6    2.475506   3.536157   4.361890   4.811397   5.055528   4.430145
# 7    2.683825   3.905490   4.718633   5.466390   5.527694   5.373322
# 8    3.007031   4.334181   5.024479   5.738590   5.995976   6.275871
# 9    3.904620   5.192256   6.095948   6.682979   7.077973   6.925438
# 10  20.000000  20.000000  20.000000  20.000000  20.000000  20.000000

# %%
prm = 'max_pred'
pred_ind_mean = []
for j in range(len(q_m500[q_z[1]]) - 1):
    line = {}
    for i in range(len(q_z) - 1):
        z_st = q_z[i]
        z_en = q_z[i + 1]
        m_st = q_m500[z_en][j]
        m_en = q_m500[z_en][j + 1]
        
        matched1 = np.logical_and(z_st <= df['z'], df['z'] < z_en)
        matched2 = np.logical_and(m_st <= df['M500'], df['M500'] < m_en)
        cur_df = df[np.logical_and(matched1, matched2)]
        pred_ind = cur_df[prm].mean()
        if np.isnan(pred_ind):
            #print(cur_df[prm])
            print(z_st, z_en, m_st, m_en)
        line['({:.2f},{:.2f})'.format(z_st, z_en)] = pred_ind
    pred_ind_mean.append(pd.DataFrame(line, index=[j]))
pred_ind_mean = pd.concat(pred_ind_mean)

# %%
cm = sns.light_palette("green", as_cmap=True)

s = pred_ind_mean.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
# #T_07d9b_row0_col0,#T_07d9b_row0_col1,#T_07d9b_row0_col3,#T_07d9b_row0_col4,#T_07d9b_row1_col2,#T_07d9b_row1_col5{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_07d9b_row0_col2{
#             background-color:  #e0eee0;
#             color:  #000000;
#         }#T_07d9b_row0_col5{
#             background-color:  #e6f1e6;
#             color:  #000000;
#         }#T_07d9b_row1_col0,#T_07d9b_row3_col5{
#             background-color:  #add5ad;
#             color:  #000000;
#         }#T_07d9b_row1_col1{
#             background-color:  #d3e7d3;
#             color:  #000000;
#         }#T_07d9b_row1_col3{
#             background-color:  #d8ead8;
#             color:  #000000;
#         }#T_07d9b_row1_col4{
#             background-color:  #cde5cd;
#             color:  #000000;
#         }#T_07d9b_row2_col0{
#             background-color:  #78bb78;
#             color:  #000000;
#         }#T_07d9b_row2_col1{
#             background-color:  #a5d1a5;
#             color:  #000000;
#         }#T_07d9b_row2_col2{
#             background-color:  #b1d7b1;
#             color:  #000000;
#         }#T_07d9b_row2_col3{
#             background-color:  #92c892;
#             color:  #000000;
#         }#T_07d9b_row2_col4{
#             background-color:  #c9e2c8;
#             color:  #000000;
#         }#T_07d9b_row2_col5{
#             background-color:  #d0e6d0;
#             color:  #000000;
#         }#T_07d9b_row3_col0{
#             background-color:  #51a851;
#             color:  #000000;
#         }#T_07d9b_row3_col1{
#             background-color:  #82c082;
#             color:  #000000;
#         }#T_07d9b_row3_col2{
#             background-color:  #8bc48b;
#             color:  #000000;
#         }#T_07d9b_row3_col3{
#             background-color:  #99cb99;
#             color:  #000000;
#         }#T_07d9b_row3_col4,#T_07d9b_row6_col5{
#             background-color:  #94c994;
#             color:  #000000;
#         }#T_07d9b_row4_col0{
#             background-color:  #7abc7a;
#             color:  #000000;
#         }#T_07d9b_row4_col1{
#             background-color:  #75b975;
#             color:  #000000;
#         }#T_07d9b_row4_col2{
#             background-color:  #369b36;
#             color:  #000000;
#         }#T_07d9b_row4_col3{
#             background-color:  #63b163;
#             color:  #000000;
#         }#T_07d9b_row4_col4{
#             background-color:  #bbdcbb;
#             color:  #000000;
#         }#T_07d9b_row4_col5{
#             background-color:  #acd4ac;
#             color:  #000000;
#         }#T_07d9b_row5_col0{
#             background-color:  #379b37;
#             color:  #000000;
#         }#T_07d9b_row5_col1{
#             background-color:  #87c287;
#             color:  #000000;
#         }#T_07d9b_row5_col2{
#             background-color:  #359a35;
#             color:  #000000;
#         }#T_07d9b_row5_col3{
#             background-color:  #60af60;
#             color:  #000000;
#         }#T_07d9b_row5_col4{
#             background-color:  #70b770;
#             color:  #000000;
#         }#T_07d9b_row5_col5{
#             background-color:  #abd4ab;
#             color:  #000000;
#         }#T_07d9b_row6_col0{
#             background-color:  #188c18;
#             color:  #000000;
#         }#T_07d9b_row6_col1{
#             background-color:  #54a954;
#             color:  #000000;
#         }#T_07d9b_row6_col2,#T_07d9b_row7_col1{
#             background-color:  #46a246;
#             color:  #000000;
#         }#T_07d9b_row6_col3{
#             background-color:  #219021;
#             color:  #000000;
#         }#T_07d9b_row6_col4{
#             background-color:  #3f9f3f;
#             color:  #000000;
#         }#T_07d9b_row7_col0{
#             background-color:  #128912;
#             color:  #f1f1f1;
#         }#T_07d9b_row7_col2{
#             background-color:  #088408;
#             color:  #f1f1f1;
#         }#T_07d9b_row7_col3,#T_07d9b_row8_col5{
#             background-color:  #299429;
#             color:  #000000;
#         }#T_07d9b_row7_col4{
#             background-color:  #319831;
#             color:  #000000;
#         }#T_07d9b_row7_col5{
#             background-color:  #40a040;
#             color:  #000000;
#         }#T_07d9b_row8_col0{
#             background-color:  #158a15;
#             color:  #000000;
#         }#T_07d9b_row8_col1{
#             background-color:  #0a850a;
#             color:  #f1f1f1;
#         }#T_07d9b_row8_col2{
#             background-color:  #028102;
#             color:  #f1f1f1;
#         }#T_07d9b_row8_col3{
#             background-color:  #249224;
#             color:  #000000;
#         }#T_07d9b_row8_col4{
#             background-color:  #108810;
#             color:  #f1f1f1;
#         }#T_07d9b_row9_col0,#T_07d9b_row9_col1,#T_07d9b_row9_col2,#T_07d9b_row9_col3,#T_07d9b_row9_col4,#T_07d9b_row9_col5{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }</style><table id="T_07d9b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >(0.00,0.11)</th>        <th class="col_heading level0 col1" >(0.11,0.19)</th>        <th class="col_heading level0 col2" >(0.19,0.27)</th>        <th class="col_heading level0 col3" >(0.27,0.36)</th>        <th class="col_heading level0 col4" >(0.36,0.50)</th>        <th class="col_heading level0 col5" >(0.50,2.00)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_07d9b_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_07d9b_row0_col0" class="data row0 col0" >0.463004</td>
#                         <td id="T_07d9b_row0_col1" class="data row0 col1" >0.480312</td>
#                         <td id="T_07d9b_row0_col2" class="data row0 col2" >0.487655</td>
#                         <td id="T_07d9b_row0_col3" class="data row0 col3" >0.382956</td>
#                         <td id="T_07d9b_row0_col4" class="data row0 col4" >0.359716</td>
#                         <td id="T_07d9b_row0_col5" class="data row0 col5" >0.289139</td>
#             </tr>
#             <tr>
#                         <th id="T_07d9b_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_07d9b_row1_col0" class="data row1 col0" >0.601347</td>
#                         <td id="T_07d9b_row1_col1" class="data row1 col1" >0.533890</td>
#                         <td id="T_07d9b_row1_col2" class="data row1 col2" >0.464434</td>
#                         <td id="T_07d9b_row1_col3" class="data row1 col3" >0.432711</td>
#                         <td id="T_07d9b_row1_col4" class="data row1 col4" >0.436806</td>
#                         <td id="T_07d9b_row1_col5" class="data row1 col5" >0.273991</td>
#             </tr>
#             <tr>
#                         <th id="T_07d9b_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_07d9b_row2_col0" class="data row2 col0" >0.716620</td>
#                         <td id="T_07d9b_row2_col1" class="data row2 col1" >0.633231</td>
#                         <td id="T_07d9b_row2_col2" class="data row2 col2" >0.588749</td>
#                         <td id="T_07d9b_row2_col3" class="data row2 col3" >0.611302</td>
#                         <td id="T_07d9b_row2_col4" class="data row2 col4" >0.446427</td>
#                         <td id="T_07d9b_row2_col5" class="data row2 col5" >0.349587</td>
#             </tr>
#             <tr>
#                         <th id="T_07d9b_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_07d9b_row3_col0" class="data row3 col0" >0.804918</td>
#                         <td id="T_07d9b_row3_col1" class="data row3 col1" >0.708416</td>
#                         <td id="T_07d9b_row3_col2" class="data row3 col2" >0.667818</td>
#                         <td id="T_07d9b_row3_col3" class="data row3 col3" >0.596263</td>
#                         <td id="T_07d9b_row3_col4" class="data row3 col4" >0.581625</td>
#                         <td id="T_07d9b_row3_col5" class="data row3 col5" >0.445245</td>
#             </tr>
#             <tr>
#                         <th id="T_07d9b_level0_row4" cla

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(10, 5))
X, Y = np.meshgrid(q_z[:-1], q_m[:-1])

Z = np.zeros_like(X)

ax.set_zticks(np.arange(0, 1.1, 0.1))
cols = list(pred_ind_mean)
for i in range(Z.shape[0]):
    for j in range(Z.shape[1]):
        Z[i,j] = pred_ind_mean[cols[j]].iloc[i]
#X, Y = np.meshgrid(list(range(len(q_z) - 1)), list(range(len(q_m) - 1)))
        
surf = ax.plot_surface(X, Y, Z, cmap='coolwarm',
                       linewidth=0, antialiased=False, alpha=0.9)

# Customize the z axis.
#ax.set_zlim(0, 1.01)
#ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
#ax.zaxis.set_major_formatter('{x:.02f}')
ax.set_xlabel('z')
ax.set_ylabel('M500')
ax.set_zlabel('<$p_{max}$>')

# Add a color bar which maps values to colors.
#fig.colorbar(surf, shrink=0.5, aspect=5)

ax.set_title(name)
plt.show()
x_scale=4
y_scale=3
z_scale=1.5

scale=np.diag([x_scale, y_scale, z_scale, 1.0])
scale=scale*(1.0/scale.max())
scale[3,3]=1.0

def short_proj():
    return np.dot(Axes3D.get_proj(ax), scale)

ax.get_proj=short_proj
